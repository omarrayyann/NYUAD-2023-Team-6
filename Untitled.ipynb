# %%
from sklearn.datasets import make_blobs

# example dataset
features, labels = make_blobs(n_samples=50, n_features=2, centers=2, random_state=3, shuffle=True)

# %%
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

features = MinMaxScaler(feature_range=(0, np.pi)).fit_transform(features)

train_features, test_features, train_labels, test_labels = train_test_split(
    features, labels, train_size=15, shuffle=False
)

# %%
# number of qubits is equal to the number of features
num_qubits = 2

# number of steps performed during the training procedure
tau = 100

# regularization parameter
C = 1000

# %%
from qiskit import BasicAer
from qiskit.circuit.library import ZFeatureMap
from qiskit.utils import algorithm_globals

from qiskit_machine_learning.kernels import FidelityQuantumKernel

algorithm_globals.random_seed = 12345

feature_map = ZFeatureMap(feature_dimension=num_qubits, reps=1)

qkernel = FidelityQuantumKernel(feature_map=feature_map)

# %%
from qiskit_machine_learning.algorithms import PegasosQSVC

# Quantum Approach

pegasos_qsvc = PegasosQSVC(quantum_kernel=qkernel, C=C, num_steps=tau)

# training
pegasos_qsvc.fit(train_features, train_labels)

# testing
pegasos_score = pegasos_qsvc.score(test_features, test_labels)
print(f"PegasosQSVC classification test score: {pegasos_score}")
# Out:
# PegasosQSVC classification test score: 1.0

# %%
grid_step = 0.2
margin = 0.2
grid_x, grid_y = np.meshgrid(
    np.arange(-margin, np.pi + margin, grid_step), np.arange(-margin, np.pi + margin, grid_step)
)
meshgrid_features = np.column_stack((grid_x.ravel(), grid_y.ravel()))
meshgrid_colors = pegasos_qsvc.predict(meshgrid_features)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 7
#       3 grid_x, grid_y = np.meshgrid(
#       4     np.arange(-margin, np.pi + margin, grid_step), np.arange(-margin, np.pi + margin, grid_step)
#       5 )
#       6 meshgrid_features = np.column_stack((grid_x.ravel(), grid_y.ravel()))
# ----> 7 meshgrid_colors = pegasos_qsvc.predict(meshgrid_features)
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit_machine_learning/algorithms/classifiers/pegasos_qsvc.py:230, in PegasosQSVC.predict(self, X)
#     208 """
#     209 Perform classification on samples in X.
#     210
#    (...)
#     226         - Pre-computed kernel matrix has the wrong shape and/or dimension.
#     227 """
#     229 t_0 = datetime.now()
# --> 230 values = self.decision_function(X)
#     231 y = np.array([self._label_pos if val > 0 else self._label_neg for val in values])
#     232 logger.debug("prediction completed after %s", str(datetime.now() - t_0)[:-7])
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit_machine_learning/algorithms/classifiers/pegasos_qsvc.py:268, in PegasosQSVC.decision_function(self, X)
#     266 values = np.zeros(X.shape[0])
#     267 for i in range(X.shape[0]):
# --> 268     values[i] = self._compute_weighted_kernel_sum(i, X, training=False)
#     270 return values
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit_machine_learning/algorithms/classifiers/pegasos_qsvc.py:296, in PegasosQSVC._compute_weighted_kernel_sum(self, index, X, training)
#     293     x_supp = self._x_train[support_indices]
#     294 if not self._precomputed:
#     295     # evaluate kernel function only for the fixed datum and the support vectors
# --> 296     kernel = self._quantum_kernel.evaluate(X[index], x_supp) + self._kernel_offset
#     297 else:
#     298     kernel = X[index, support_indices]
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit_machine_learning/kernels/fidelity_quantum_kernel.py:92, in FidelityQuantumKernel.evaluate(self, x_vec, y_vec)
#      91 def evaluate(self, x_vec: np.ndarray, y_vec: np.ndarray | None = None) -> np.ndarray:
# ---> 92     x_vec, y_vec = self._validate_input(x_vec, y_vec)
#      94     # determine if calculating self inner product
#      95     is_symmetric = True
#
# File /opt/.qbraid/environments/qbraid_000000/pyenv/lib/python3.9/site-packages/qiskit_machine_learning/kernels/base_kernel.py:132, in BaseKernel._validate_input(self, x_vec, y_vec)
#     129         raise ValueError("y_vec must be a 1D or 2D array")
#     131     if y_vec.shape[1] != x_vec.shape[1]:
# --> 132         raise ValueError(
#     133             "x_vec and y_vec have incompatible dimensions.\n"
#     134             f"x_vec has {x_vec.shape[1]} dimensions, but y_vec has {y_vec.shape[1]}."
#     135         )
#     137 return x_vec, y_vec
#
# ValueError: x_vec and y_vec have incompatible dimensions.
# x_vec has 2 dimensions, but y_vec has 10.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 5))
meshgrid_colors = meshgrid_colors.reshape(grid_x.shape)
plt.pcolormesh(grid_x, grid_y, meshgrid_colors, cmap="RdBu", shading="auto")

plt.scatter(
    train_features[:, 0][train_labels == 0],
    train_features[:, 1][train_labels == 0],
    marker="s",
    facecolors="w",
    edgecolors="r",
    label="A train",
)
plt.scatter(
    train_features[:, 0][train_labels == 1],
    train_features[:, 1][train_labels == 1],
    marker="o",
    facecolors="w",
    edgecolors="b",
    label="B train",
)

plt.scatter(
    test_features[:, 0][test_labels == 0],
    test_features[:, 1][test_labels == 0],
    marker="s",
    facecolors="r",
    edgecolors="r",
    label="A test",
)
plt.scatter(
    test_features[:, 0][test_labels == 1],
    test_features[:, 1][test_labels == 1],
    marker="o",
    facecolors="b",
    edgecolors="b",
    label="B test",
)

plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
plt.title("Pegasos Classification")
plt.show()

# %%
# Classical Approach

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score , confusion_matrix , recall_score , precision_score

model_svm=SVC(kernel="rbf")
model_svm.fit(train_features,train_labels)
predictions=model_svm.predict(test_features)

SVM_accuracy = accuracy_score(test_labels,predictions)*100
print("Accuracy_score : ", SVM_accuracy)
# Out:
# Accuracy_score :  100.0

# %%
import matplotlib.pyplot as plt

grid_step = 0.2
margin = 0.2
grid_x, grid_y = np.meshgrid(
    np.arange(-margin, np.pi + margin, grid_step), np.arange(-margin, np.pi + margin, grid_step)
)
meshgrid_features = np.column_stack((grid_x.ravel(), grid_y.ravel()))
meshgrid_colors = model_svm.predict(meshgrid_features)

plt.figure(figsize=(5, 5))
meshgrid_colors = meshgrid_colors.reshape(grid_x.shape)
plt.pcolormesh(grid_x, grid_y, meshgrid_colors, cmap="RdBu", shading="auto")

plt.scatter(
    train_features[:, 0][train_labels == 0],
    train_features[:, 1][train_labels == 0],
    marker="s",
    facecolors="w",
    edgecolors="r",
    label="A train",
)
plt.scatter(
    train_features[:, 0][train_labels == 1],
    train_features[:, 1][train_labels == 1],
    marker="o",
    facecolors="w",
    edgecolors="b",
    label="B train",
)

plt.scatter(
    test_features[:, 0][test_labels == 0],
    test_features[:, 1][test_labels == 0],
    marker="s",
    facecolors="r",
    edgecolors="r",
    label="A test",
)
plt.scatter(
    test_features[:, 0][test_labels == 1],
    test_features[:, 1][test_labels == 1],
    marker="o",
    facecolors="b",
    edgecolors="b",
    label="B test",
)

plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left", borderaxespad=0.0)
plt.title("Pegasos Classification")
plt.show()
